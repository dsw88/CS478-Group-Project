# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('./data-3-17-18.csv')

# %% [markdown]
# ## Feature Analysis
# First, let's see what the first few rows of data look like:

# %%
df.head(5)
# Out:
#    listing_id                vin       make    model  year condition  \
# 0   728415150  3FA6P0H74HR194881       Ford   Fusion  2017      Used
# 1   728303275  4S4BSELC9F3220245     Subaru  Outback  2015      Used
# 2   728300268  2GNALCEK8G6120080  Chevrolet  Equinox  2016      Used
# 3   728297986  WBAKA83509CY35097        BMW     750i  2009      Used
# 4   728283238  4T1BF1FK9FU075606     Toyota    Camry  2015      Used
#
#    mpg_city  mpg_highway fuel_type  mileage          ...            \
# 0      23.0         25.0  Gasoline   9554.0          ...
# 1      22.0         28.0  Gasoline  68066.0          ...
# 2      23.0         26.0  Gasoline  59118.0          ...
# 3      18.0         18.0  Gasoline  89500.0          ...
# 4      25.0         28.0  Gasoline  36292.0          ...
#
#    interior_color                        transmission cars_rating  \
# 0             NaN                   6-Speed Automatic         4.9
# ...

# %% [markdown]
# Let's look at the distribution of prices:

# %%
# %matplotlib inline
model_counts = df['model'].value_counts()
for item in model_counts.iteritems():
    print(item)
#sorted_by_price = df.sort_values(by='price', ascending=False)
#sorted_by_price[['year','price']].set_index('price').hist()
# Out:
# ('F-150', 1032)
# ('Silverado', 947)
# ('Altima', 643)
# ('Camry', 639)
# ('Accord', 595)
# ('Rogue', 542)
# ('Civic', 519)
# ('Wrangler', 510)
# ('Corolla', 490)
# ('Grand Cherokee', 487)
# ('Sierra', 480)
# ('Escape', 435)
# ('Fusion', 425)
# ('Sentra', 423)
# ('1500', 418)
# ('Sonata', 417)
# ('Explorer', 405)
# ('CR-V', 396)
# ('Ram', 392)
# ('RAV4', 384)
# ('Cruze', 382)
# ('Malibu', 379)
# ('Focus', 371)
# ('C-Class', 365)
# ('Elantra', 359)
# ('Equinox', 358)
# ('Passat', 347)
# ('Tacoma', 337)
# ('Tundra', 310)
# ('RX', 307)
# ('Tahoe', 306)
# ('Jetta', 305)
# ('Pilot', 294)
# ('Optima', 292)
# ('Mustang', 286)
# ('Camaro', 280)
# ('Acadia', 273)
# ('4-Runner', 272)
# ('Traverse', 267)
# ('Maxima', 265)
# ('F-250', 256)
# ('Cherokee', 254)
# ('Highlander', 254)
# ('Edge', 253)
# ('IS', 244)
# ('Soul', 242)
# ('Pathfinder', 242)
# ('E-Class', 238)
# ('Santa Fe', 238)
# ('Odyssey', 238)
# ('Sienna', 234)
# ('ES', 233)
# ('Impala', 225)
# ('Suburban', 222)
# ('328i', 219)
# ...
